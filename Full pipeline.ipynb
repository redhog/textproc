# %%
# %pylab inline
import json
import textproc.pipeline
import yaml
import asyncio
import aiostream.stream
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
with open('../Case - Editorial -Data Scientist/data/dn_articles.json') as f:
    data = json.load(f)

# %% [markdown]
# # Article enrichment pipeline
#
# The following pipeline extracts metadata from the article bodies and lead texts.
# It also looks up people and companies on wikipedia, and extracts relevant metadata from the wikipedia articles.
#
# The pipeline is written as a DSL using YAML syntax. In this DSL, a pipeline is formed from steps that each have a function name and some function specific parameters.
#
# The main functions are: templated (calls an LLM), each (runs a sub pipeline over some JSON field) and wikipedia (downloads wikipedia articles).
#
# The DSL makes heavy use of json paths (for json field lookups) and jinja templates (for prompts). Note the extension of jinja templates allowing json paths as template variables.

# %%
pipeline = textproc.pipeline.Pipeline(yaml.safe_load("""
steps:
 - templated:
     description: Extract metadata
     
     prompt: |
       Below follows a newspaper article
       
       * Summarize the article into a single paragraph.
       * Suggest a new title for the following newspaper article. Don't make it too long, it will go on the webpage front page.
       * Extract any key phrases and keywords.
       * Extract any person, company (or other organization) mentioned

       # {{$.title}}
     
       {{$.lead_text}}

       {{$.body}}
     
     output_schema:
       type: object
       properties:
         summary:
           type: string
         suggested_title:
           type: string
         key_phrases:
           type: array
           items:
             type: string
         people:
           type: array
           items:
             type: string
         companies:
           type: array
           items:
             type: string
             
 - wikipedia:
     description: Download data on people
     input_key: $.people
     language: "no"
     
 - each:
     description: Extract data on people
     
     input_key: $.people
     steps:
         - templated:
             description: Extract metadata from a wikipedia article on a person
                            
             prompt: |
               Here follows part of a wikipedia article about a person.
               Extracyt a summary, as well as a list of roles they've had:
        
               {{$.content}}

             output_schema:
               type: object
               properties:
                 summary:
                   type: string
                 roles:
                   type: array
                   items:
                     type: string

 - wikipedia:
     description: Download data on companies
     input_key: $.companies
     language: "no"

 - each:
     description: Extract data on companies
     
     input_key: $.companies
     steps:
         - templated:             
             prompt: |
               Here follows port of a wikipedia article about a company or other organization.
               Extracyt a summary, as well as a list of major events related to the company:
        
               {{$.content}}
               
             output_schema:
               type: object
               properties:
                 summary:
                   type: string
                 events:
                   type: array
                   items:
                     type: string
 
"""))

# %% [markdown]
# # Running a pipeline
#
# To run a pipeline, we just supply an (async) iterator or list as input, and get an async iterator as output.
# To turn that into a normal list, we use aiostream.stream.list.

# %%
out = await aiostream.stream.list(pipeline.run(data[:1]))
# Out:
# 2025-11-01 20:46:49,460 - textproc.pipeline - INFO - Executing Extract metadata
# 2025-11-01 20:46:49,463 - textproc.pipeline - INFO - Executing Download data on people
# 2025-11-01 20:46:49,465 - textproc.pipeline - INFO - Executing Extract data on people
# 2025-11-01 20:46:49,467 - textproc.pipeline - INFO - Executing Download data on companies
# 2025-11-01 20:46:49,468 - textproc.pipeline - INFO - Executing Extract data on companies
# 2025-11-01 20:46:49,498 - textproc.filters.templated - INFO - LLM call
# AAAAAAAAAAAAAAA no
# XXXXXXXXXXXXX no
# AAAAAAAAAAAAAAA no
# XXXXXXXXXXXXX no
# AAAAAAAAAAAAAAA no
# XXXXXXXXXXXXX no
# AAAAAAAAAAAAAAA no
# XXXXXXXXXXXXX no
# AAAAAAAAAAAAAAA no
# XXXXXXXXXXXXX no
# AAAAAAAAAAAAAAA no
# XXXXXXXXXXXXX no
# 2025-11-01 20:47:11,085 - textproc.pipeline - INFO - Executing Extract metadata from a wikipedia article on a person
# 2025-11-01 20:47:11,092 - textproc.filters.templated - INFO - LLM call
# 2025-11-01 20:47:11,100 - textproc.filters.templated - INFO - LLM call
# 2025-11-01 20:47:11,110 - textproc.filters.templated - INFO - LLM call
# 2025-11-01 20:47:11,119 - textproc.filters.templated - INFO - LLM call
# 2025-11-01 20:47:11,130 - textproc.filters.templated - INFO - LLM call
# 2025-11-01 20:47:26,567 - textproc.filters.templated - INFO - LLM call
# AAAAAAAAAAAAAAA no
# XXXXXXXXXXXXX no
# AAAAAAAAAAAAAAA no
# XXXXXXXXXXXXX no
# AAAAAAAAAAAAAAA no
# XXXXXXXXXXXXX no
# AAAAAAAAAAAAAAA no
# XXXXXXXXXXXXX no
# AAAAAAAAAAAAAAA no
# XXXXXXXXXXXXX no
# AAAAAAAAAAAAAAA no
# XXXXXXXXXXXXX no
# AAAAAAAAAAAAAAA no
# XXXXXXXXXXXXX no
# AAAAAAAAAAAAAAA no
# XXXXXXXXXXXXX no
# AAAAAAAAAAAAAAA no
# XXXXXXXXXXXXX no
# 2025-11-01 20:47:47,774 - textproc.pipeline - INFO - Executing templated
# 2025-11-01 20:47:47,781 - textproc.filters.templated - INFO - LLM call
# 2025-11-01 20:47:47,788 - textproc.filters.templated - INFO - LLM call
# 2025-11-01 20:47:47,796 - textproc.filters.templated - INFO - LLM call
# 2025-11-01 20:47:47,806 - textproc.filters.templated - INFO - LLM call
# 2025-11-01 20:47:47,814 - textproc.filters.templated - INFO - LLM call
# 2025-11-01 20:47:57,425 - textproc.filters.templated - INFO - LLM call
# 2025-11-01 20:47:59,579 - textproc.filters.templated - INFO - LLM call
# 2025-11-01 20:48:16,471 - textproc.filters.templated - INFO - LLM call
# 2025-11-01 20:48:17,780 - textproc.filters.templated - INFO - LLM call

# %% [markdown]
# # Exploring the output
#
# The output data items contain all the fields of the input data items (unless overwritten),
# plus any new fields created by the pipeline steps

# %%
out[0].keys()
# Out:
# dict_keys(['ingestiontime', 'publication_lantern', 'content_id', 'published_at', 'updated_at', 'content_type', 'content_sub_type', 'authors', 'title', 'lead_text', 'body', 'categories', 'topics', 'inline', 'lead_image_url', 'summary', 'suggested_title', 'key_phrases', 'people', 'companies'])

# %%
len(out[0]["people"])
# Out:
# 6

# %%
len(out[0]["companies"])
# Out:
# 9

# %%
out[0]["people"][0]["name"]
# Out:
# 'María Corina Machado'

# %%
out[0]["people"][0]["summary"]
# Out:
# "María Corina Machado Parisca (born 1967) is a Venezuelan engineer, industrial economist, human-rights activist and opposition politician. She founded and led the election-observation organisation Súmate, served as a deputy in Venezuela's National Assembly for Miranda (2011–2014), and is the national coordinator of the party Vente Venezuela. Machado has been barred from domestic political activity by the Maduro government and has received international recognition, including the 2024 Sakharov Prize, the 2024 Václav Havel Prize and the 2025 Nobel Peace Prize."

# %%
out[0]["people"][0]["roles"]
# Out:
# ['Engineer and industrial economist',
#  'Human-rights activist',
#  'Opposition politician',
#  'Founder and leader of Súmate (2002–2010)',
#  "Member of Venezuela's National Assembly, deputy for Miranda (2011–2014)",
#  'National coordinator of Vente Venezuela (2012–present)',
#  'Nobel Peace Prize laureate (2025)',
#  'Sakharov Prize laureate (2024)',
#  'Václav Havel Prize for Human Rights laureate (2024)',
#  'BBC 100 Women honoree (2018)']

# %% [markdown]
# ## We are a bit unlucky regarding companies 0 and 1, their wikipedia articles are *disambiguation articles*, and currenbtly there's no code to recurse through that.

# %%
out[0]["companies"][2]["name"]
# Out:
# 'Sikkerhetsrådet (UN Security Council)'

# %%
out[0]["companies"][2]["summary"]
# Out:
# 'FNs sikkerhetsråd (United Nations Security Council) er FNs hovedorgan for internasjonal fred og sikkerhet, opprettet i 1945 gjennom FN-pakten. Rådet har 15 medlemmer — fem faste (USA, Storbritannia, Frankrike, Russland, Kina) med vetorett — og ti ikke-permanente medlemmer valgt for toårige perioder. Sikkerhetsrådet alene kan autorisere fredsbevarende operasjoner; presidentskapet rullerer månedlig.'

# %%
out[0]["companies"][2]["events"]
# Out:
# ['1945: Sikkerhetsrådet ble opprettet gjennom De forente nasjoners pakt som FN‑s hovedorgan for å opprettholde internasjonal fred og sikkerhet.',
#  'Tidligere forhold: Folkeforbundet hadde et tilsvarende beslutningsråd med faste medlemmer før FN.',
#  'Fra 1945: De fem faste medlemmene (USA, Storbritannia, Frankrike, Russland/USSR, Kina) fikk vetorett — substantielle vedtak krever minst ni stemmer og ingen negativ stemme fra et fast medlem.',
#  '1971: Setet for Kina i Sikkerhetsrådet gikk fra Republikken Kina (Taiwan) til Folkerepublikken Kina.',
#  'Norge har vært valgt til Sikkerhetsrådet i periodene 1949–1950, 1963–1964, 1979–1980, 2001–2002 og 2021–2022; FN‑general‑forsamlingen valgte Norge for 2021–2022 den 17. juni 2020.',
#  'Norges bidrag til FN‑bygningen i New York: Sikkerhetsrådets møterom ble donert og utformet av Arnstein Arneberg, med veggdekorasjon malt av Per Krohg.',
#  'Tidlig 2000‑tall: Generalsekretær Kofi Annan ba om forslag til reform av FNs struktur, inkludert forslag om å utvide antallet faste medlemmer i Sikkerhetsrådet.',
#  '2004: G4‑landene (Japan, Tyskland, India, Brasil) undertegnet en felles uttalelse som gjensidig støttet krav om faste seter; Tyskland og Japan førte aktive kampanjer for permanent medlemskap.',
#  'USA har uttalt støtte til å opprette to permanente seter for afrikanske land i forbindelse med en eventuell utvidelse av Sikkerhetsrådet.',
#  'Sikkerhetsrådet velger jevnlig ikke‑permanente medlemmer for toårsperioder — for eksempel ble Estonia, Niger, Saint Vincent og Grenadinene, Tunisia og Vietnam valgt for 2020–2021.',
#  'Presidentskapet i Sikkerhetsrådet rullerer månedlig; 2023‑presidentskapet inkluderte blant andre Japan (jan), Malta (feb), Mosambik (mar), Russland (apr), Sveits (mai), UAE (jun) og Kina (nov).',
#  'Sikkerhetsrådet er det eneste FN‑organet som kan autorisere utsendelse av fredsbevarende styrker.']

# %%
print(out[0]["companies"][2]["content"])
# Out:
# FNs sikkerhetsråd
# ---
# [engelsk](/wiki/Engelsk_\(spr%C3%A5k\) "Engelsk \(språk\)")| United Nations
# Security Council
# [fransk](/wiki/Fransk_\(spr%C3%A5k\) "Fransk \(språk\)")| Conseil de sécurité
# des Nations unies
# [![](//upload.wikimedia.org/wikipedia/commons/thumb/5/52/Emblem_of_the_United_Nations.svg/120px-
# Emblem_of_the_United_Nations.svg.png)](/wiki/Fil:Emblem_of_the_United_Nations.svg)
# [![](//upload.wikimedia.org/wikipedia/commons/thumb/9/95/UN-Sicherheitsrat_-
# _UN_Security_Council_-_New_York_City_-_2014_01_06.jpg/250px-UN-
# Sicherheitsrat_-_UN_Security_Council_-
# _New_York_City_-_2014_01_06.jpg)](/wiki/Fil:UN-Sicherheitsrat_-
# _UN_Security_Council_-_New_York_City_-_2014_01_06.jpg)
# Grunnlagt| 1945
# System| [FN](/wiki/FN "FN")
# Kammer| hovedorgan i De forente nasjoner, [råd](/wiki/Nemnd "Nemnd")
# Seter| 15
# Møtested| [FN-bygningen](/wiki/FN-bygningen "FN-bygningen")
# Nettsted| <https://www.un.org/securitycouncil>
# [![](//upload.wikimedia.org/wikipedia/commons/thumb/a/aa/United_Nations_Security_Council_regional_groups.svg/250px-
# United_Nations_Security_Council_regional_groups.svg.png)](/wiki/Fil:United_Nations_Security_Council_regional_groups.svg)
# [![](//upload.wikimedia.org/wikipedia/commons/thumb/9/91/Map_of_UN_security_council_members.svg/250px-
# Map_of_UN_security_council_members.svg.png)](/wiki/Fil:Map_of_UN_security_council_members.svg)
#
# * * *
#
# [FNs sikkerhetsråd på
# Commons](https://commons.wikimedia.org/wiki/Category:United_Nations_Security_Council
# "commons:Category:United Nations Security Council")
# [![](//upload.wikimedia.org/wikipedia/commons/thumb/3/35/United_Nations_Security_Council.jpg/250px-
# United_Nations_Security_Council.jpg)](/wiki/Fil:United_Nations_Security_Council.jpg)Salen
# der sikkerhetsrådet møtes, i [FN-bygningen](/wiki/FN-bygningen "FN-bygningen")
# i [New York](/wiki/New_York "New York").
#
# Foto: Patrick Gruban (2006)
#
# [![](//upload.wikimedia.org/wikipedia/commons/thumb/8/82/Barack_Obama_chairs_a_United_Nations_Security_Council_meeting.jpg/250px-
# Barack_Obama_chairs_a_United_Nations_Security_Council_meeting.jpg)](/wiki/Fil:Barack_Obama_chairs_a_United_Nations_Security_Council_meeting.jpg)[Barack
# Obama](/wiki/Barack_Obama "Barack Obama") leder et møte i FNs sikkerhetsråd
# 24. september 2009.
#
# Foto: Pete Souza
#
# **FNs sikkerhetsråd** er ifølge [FN-pakten](/wiki/De_forente_nasjoners_pakt
# "De forente nasjoners pakt") [FNs](/wiki/FN "FN") handlingsorgan, og er det
# organet med mest makt innen hele FN, ettersom det kun er Sikkerhetsrådet som
# kan utsende fredsbevarende styrker. Alle medlemsland må følge rådets vedtak.
# Stormaktene [USA](/wiki/USA "USA"), [Frankrike](/wiki/Frankrike "Frankrike"),
# [Kina](/wiki/Kina "Kina"), [Russland](/wiki/Russland "Russland") og
# [Storbritannia](/wiki/Storbritannia "Storbritannia") er faste medlemmer med
# vetorett og kan forhindre foreslåtte vedtak.
#
# Formannsskapet i Sikkerhetsrådet rullerer hver måned mellom rådets medlemmer.
#
# ## Forløper
#
# [[rediger](/w/index.php?title=FNs_sikkerhetsr%C3%A5d&veaction=edit&section=1 "Rediger avsnitt: Forløper") | [rediger kilde](/w/index.php?title=FNs_sikkerhetsr%C3%A5d&action=edit&section=1 "Rediger kildekoden til seksjonen Forløper")]
#
# [Folkeforbundet](/wiki/Folkeforbundet "Folkeforbundet") hadde et tilsvarende
# råd, som tok de fleste beslutningene. Dette rådet bestod av fem permanente
# medlemmer ([Storbritannia](/wiki/Storbritannia "Storbritannia"),
# [Frankrike](/wiki/Frankrike "Frankrike"), [Italia](/wiki/Italia "Italia"),
# [Japan](/wiki/Japan "Japan") og [Tyskland](/wiki/Tyskland "Tyskland")) og et
# varierende antall (først fire, siden seks og ni) valgte medlemmer.
#
# ## Vetoretten
#
# [[rediger](/w/index.php?title=FNs_sikkerhetsr%C3%A5d&veaction=edit&section=2 "Rediger avsnitt: Vetoretten") | [rediger kilde](/w/index.php?title=FNs_sikkerhetsr%C3%A5d&action=edit&section=2 "Rediger kildekoden til seksjonen Vetoretten")]
#
# Når det gjelder rene prosedyrespørsmål, spørsmål om hvordan rådet skal jobbe,
# kreves det ni stemmers flertall. I alle andre saker kreves det også at ingen
# av de faste medlemmene stemmer mot. Det er dette som er kjent som
# vetoretten.[1]
#
# Kina, Russland, Frankrike, Storbritannia og USA må enten stemme for, eller
# avstå fra å stemme, dersom en resolusjon skal gå gjennom.
#
# ## Møtesalen
#
# [[rediger](/w/index.php?title=FNs_sikkerhetsr%C3%A5d&veaction=edit&section=3 "Rediger avsnitt: Møtesalen") | [rediger kilde](/w/index.php?title=FNs_sikkerhetsr%C3%A5d&action=edit&section=3 "Rediger kildekoden til seksjonen Møtesalen")]
#
# [![](//upload.wikimedia.org/wikipedia/commons/thumb/7/7d/Kazakh_Presidency_at_UNSC.jpg/250px-
# Kazakh_Presidency_at_UNSC.jpg)](/wiki/Fil:Kazakh_Presidency_at_UNSC.jpg)Utsnitt
# av Per Kroghs bilde for enden av rommet. Figurene på bildet minner om Krogh og
# hans kone.[2]
#
# Sikkerhetsrådet har et eget møterom i FN-bygningen. Rommet var Norges bidrag
# til FN-bygget og ble utformet av [Arnstein Arneberg](/wiki/Arnstein_Arneberg
# "Arnstein Arneberg"). [Per Krohg](/wiki/Per_Krohg "Per Krohg") malte
# veggdekorasjonen.[2]
#
# ## Utvidelse
#
# [[rediger](/w/index.php?title=FNs_sikkerhetsr%C3%A5d&veaction=edit&section=4 "Rediger avsnitt: Utvidelse") | [rediger kilde](/w/index.php?title=FNs_sikkerhetsr%C3%A5d&action=edit&section=4 "Rediger kildekoden til seksjonen Utvidelse")]
#
# Det har vært diskutert å utvide antall permanente medlemmer. De landene som
# har markert seg med de sterkeste kravene om fast sete, [Japan](/wiki/Japan
# "Japan") og [Tyskland](/wiki/Tyskland "Tyskland"), er FNs andre og tredje
# største netto bidragsytere. Tyskland er også den nest største bidragsyteren av
# tropper til FN-operasjoner etter USA. Kansler [Gerhard
# Schröder](/wiki/Gerhard_Schr%C3%B6der "Gerhard Schröder") sa i august 2004
# rett og slett: «Tyskland har rett til et sete».
#
# Tidligere generalsekretær [Kofi Annan](/wiki/Kofi_Annan "Kofi Annan") ba sine
# rådgivere om å fremme et forslag til hvordan FNs struktur kan reformeres. En
# foreslått løsning er å utvide antallet faste medlemmer av sikkerhetsrådet med
# fem, til å inkluderere Japan, Tyskland, India, Brasil og et afrikansk land. I
# september 2004 undertegnet disse fire landene en felles uttalelse hvor de
# gjensidig støtter hverandres krav om fast plass. Storbritannia og Frankrike
# erklærte at de støtter dette kravet.
#
# Noen land, bl.a. Italia og Nederland, ønsker et felles [europeisk](/wiki/EU
# "EU") sete. Men siden det er lite sannsynlig at Storbritannia og Frankrike
# ønsker å gi opp sine egne seter, bør Tyskland, som er et mye større land, også
# få et sete, ifølge den tyske utenriksministeren. USA støtter opprettelsen av
# to permanente seter i Sikkerhetsrådet for afrikanske land, i tilfelle
# utvidelse av Sikkerhetsrådet.
#
# ## Medlemsland
#
# [[rediger](/w/index.php?title=FNs_sikkerhetsr%C3%A5d&veaction=edit&section=5 "Rediger avsnitt: Medlemsland") | [rediger kilde](/w/index.php?title=FNs_sikkerhetsr%C3%A5d&action=edit&section=5 "Rediger kildekoden til seksjonen Medlemsland")]
#
# ### Faste medlemsland
#
# [[rediger](/w/index.php?title=FNs_sikkerhetsr%C3%A5d&veaction=edit&section=6 "Rediger avsnitt: Faste medlemsland") | [rediger kilde](/w/index.php?title=FNs_sikkerhetsr%C3%A5d&action=edit&section=6 "Rediger kildekoden til seksjonen Faste medlemsland")]
#
#   * Kina:
#     * [Republikken Kina (Taiwan)](/wiki/Republikken_Kina_\(Taiwan\) "Republikken Kina \(Taiwan\)") (til 1971)[3]
#     * [Folkerepublikken Kina](/wiki/Folkerepublikken_Kina "Folkerepublikken Kina") (fra 1971)
#   * [Frankrike](/wiki/Frankrike "Frankrike")
#   * [Russland](/wiki/Russland "Russland")
#   * [USA](/wiki/USA "USA")
#   * [Storbritannia](/wiki/Storbritannia "Storbritannia")
#
# ### Rullerende medlemsland
#
# [[rediger](/w/index.php?title=FNs_sikkerhetsr%C3%A5d&veaction=edit&section=7 "Rediger avsnitt: Rullerende medlemsland") | [rediger kilde](/w/index.php?title=FNs_sikkerhetsr%C3%A5d&action=edit&section=7 "Rediger kildekoden til seksjonen Rullerende medlemsland")]
#
# **Valgt for perioden 2019–2020**
#
#   * [Belgia](/wiki/Belgia "Belgia")
#   * [Den dominikanske republikk](/wiki/Den_dominikanske_republikk "Den dominikanske republikk")
#   * [Indonesia](/wiki/Indonesia "Indonesia")
#   * [Sør-Afrika](/wiki/S%C3%B8r-Afrika "Sør-Afrika")
#   * [Tyskland](/wiki/Tyskland "Tyskland")
#
# **Valgt for perioden 2020–2021**[4]
#
#   * [Estland](/wiki/Estland "Estland")
#   * [Niger](/wiki/Niger "Niger")
#   * [Saint Vincent og Grenadinene](/wiki/Saint_Vincent_og_Grenadinene "Saint Vincent og Grenadinene")
#   * [Tunisia](/wiki/Tunisia "Tunisia")
#   * [Vietnam](/wiki/Vietnam "Vietnam")
#
# **Valgt for perioden 2021–2022:**[5][6]
#
#   * [Irland](/wiki/Irland "Irland")
#   * [India](/wiki/India "India")
#   * [Kenya](/wiki/Kenya "Kenya")
#   * [Mexico](/wiki/Mexico "Mexico")
#   * [Norge](/wiki/Norge "Norge")
#
# **Valgt for perioden 2022–2023:**[7]
#
#   * [Albania](/wiki/Albania "Albania")
#   * [Brasil](/wiki/Brasil "Brasil")
#   * [De forente arabiske emirater](/wiki/De_forente_arabiske_emirater "De forente arabiske emirater")
#   * [Gabon](/wiki/Gabon "Gabon")
#   * [Ghana](/wiki/Ghana "Ghana")
#
# **Valgt for perioden 2023–2024:**
#
#   * [Ecuador](/wiki/Ecuador "Ecuador")
#   * [Japan](/wiki/Japan "Japan")
#   * [Malta](/wiki/Malta "Malta")
#   * [Mosambik](/wiki/Mosambik "Mosambik")
#   * [Sveits](/wiki/Sveits "Sveits")
#
# **Valgt for perioden 2025–2026:**
#
#   * [Danmark](/wiki/Danmark "Danmark")
#   * [Hellas](/wiki/Hellas "Hellas")
#   * [Panama](/wiki/Panama "Panama")
#   * [Pakistan](/wiki/Pakistan "Pakistan")
#   * [Somalia](/wiki/Somalia "Somalia")
#
# #### Norge
#
# [[rediger](/w/index.php?title=FNs_sikkerhetsr%C3%A5d&veaction=edit&section=8 "Rediger avsnitt: Norge") | [rediger kilde](/w/index.php?title=FNs_sikkerhetsr%C3%A5d&action=edit&section=8 "Rediger kildekoden til seksjonen Norge")]
#
# [Norge](/wiki/Norge "Norge") har vært medlem av Sikkerhetsrådet fem ganger, i
# periodene [1949](/wiki/1949 "1949")–[1950](/wiki/1950 "1950"),
# [1963](/wiki/1963 "1963")–[1964](/wiki/1964 "1964"), [1979](/wiki/1979
# "1979")–[1980](/wiki/1980 "1980"), [2001](/wiki/2001 "2001")–[2002](/wiki/2002
# "2002") og [2021](/wiki/2021 "2021")–[2022](/wiki/2022 "2022").[8][9] FNs
# generalforsamling valgte i sitt møte 17. juni 2020 Norge som medlem av
# sikkerhetsrådet for perioden 2021–2022.[10]
#
# Norge hadde sist formannskapet i Sikkerhetsrådet i mars 2002, og arbeidet ble
# ledet av ambassadør [Ole Peter Kolby](/wiki/Ole_Peter_Kolby "Ole Peter
# Kolby").[11] Dessuten har Norge i en årrekke stilt militære styrker til
# rådighet for [FNs fredsbevarende styrker](/wiki/FNs_fredsbevarende_styrker
# "FNs fredsbevarende styrker") som er underlagt Sikkerhetsrådet.
#
# ## Presidentskap 2023
#
# [[rediger](/w/index.php?title=FNs_sikkerhetsr%C3%A5d&veaction=edit&section=9 "Rediger avsnitt: Presidentskap 2023") | [rediger kilde](/w/index.php?title=FNs_sikkerhetsr%C3%A5d&action=edit&section=9 "Rediger kildekoden til seksjonen Presidentskap 2023")]
#
# Presidentskap i 2023  Månd  | Land[12]
# ---|---
# Januar  | [![Japans flagg](//upload.wikimedia.org/wikipedia/commons/thumb/9/9e/Flag_of_Japan.svg/40px-Flag_of_Japan.svg.png)](/wiki/Japan "Japan") [Japan](/wiki/Japan "Japan")
# Februar  | [![Maltas flagg](//upload.wikimedia.org/wikipedia/commons/thumb/7/73/Flag_of_Malta.svg/40px-Flag_of_Malta.svg.png)](/wiki/Malta "Malta") [Malta](/wiki/Malta "Malta")
# Mars  | [![Mosambiks flagg](//upload.wikimedia.org/wikipedia/commons/thumb/d/d0/Flag_of_Mozambique.svg/40px-Flag_of_Mozambique.svg.png)](/wiki/Mosambik "Mosambik") [Mosambik](/wiki/Mosambik "Mosambik")
# April  | [![Russlands flagg](//upload.wikimedia.org/wikipedia/commons/thumb/f/f3/Flag_of_Russia.svg/40px-Flag_of_Russia.svg.png)](/wiki/Russland "Russland") [Russland](/wiki/Russland "Russland")
# Mai  | [![Sveits’ flagg](//upload.wikimedia.org/wikipedia/commons/thumb/f/f3/Flag_of_Switzerland.svg/20px-Flag_of_Switzerland.svg.png)](/wiki/Sveits "Sveits") [Sveits](/wiki/Sveits "Sveits")
# Juni  | [![De forente arabiske emiraters flagg](//upload.wikimedia.org/wikipedia/commons/thumb/c/cb/Flag_of_the_United_Arab_Emirates.svg/40px-Flag_of_the_United_Arab_Emirates.svg.png)](/wiki/De_forente_arabiske_emirater "De forente arabiske emirater") [De forente arabiske emirater](/wiki/De_forente_arabiske_emirater "De forente arabiske emirater")
# Juli  | [![Storbritannias flagg](//upload.wikimedia.org/wikipedia/commons/thumb/8/83/Flag_of_the_United_Kingdom_%283-5%29.svg/40px-Flag_of_the_United_Kingdom_%283-5%29.svg.png)](/wiki/Storbritannia "Storbritannia") [Storbritannia](/wiki/Storbritannia "Storbritannia")
# August  | [![De forente arabiske emiraters flagg](//upload.wikimedia.org/wikipedia/commons/thumb/c/cb/Flag_of_the_United_Arab_Emirates.svg/40px-Flag_of_the_United_Arab_Emirates.svg.png)](/wiki/De_forente_arabiske_emirater "De forente arabiske emirater") [De forente arabiske emirater](/wiki/De_forente_arabiske_emirater "De forente arabiske emirater")
# September  | [![Albanias flagg](//upload.wikimedia.org/wikipedia/commons/thumb/3/36/Flag_of_Albania.svg/40px-Flag_of_Albania.svg.png)](/wiki/Albania "Albania") [Albania](/wiki/Albania "Albania")
# Oktober  | [![Brasils flagg](//upload.wikimedia.org/wikipedia/commons/thumb/0/05/Flag_of_Brazil.svg/40px-Flag_of_Brazil.svg.png)](/wiki/Brasil "Brasil") [Brasil](/wiki/Brasil "Brasil")
# November  | [![Kinas flagg](//upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/40px-Flag_of_the_People%27s_Republic_of_China.svg.png)](/wiki/Kina "Kina") [Kina](/wiki/Kina "Kina")
# Desember  | [![Ecuadors flagg](//upload.wikimedia.org/wikipedia/commons/thumb/e/e8/Flag_of_Ecuador.svg/40px-Flag_of_Ecuador.svg.png)](/wiki/Ecuador "Ecuador") [Ecuador](/wiki/Ecuador "Ecuador")
#
# ## Se også
#
# [[rediger](/w/index.php?title=FNs_sikkerhetsr%C3%A5d&veaction=edit&section=10 "Rediger avsnitt: Se også") | [rediger kilde](/w/index.php?title=FNs_sikkerhetsr%C3%A5d&action=edit&section=10 "Rediger kildekoden til seksjonen Se også")]
#
#   * [Valg til FNs sikkerhetsråd (januar 1946)](/wiki/Valg_til_FNs_sikkerhetsr%C3%A5d_\(januar_1946\) "Valg til FNs sikkerhetsråd \(januar 1946\)")
#
# ## Referanser
#
# [[rediger](/w/index.php?title=FNs_sikkerhetsr%C3%A5d&veaction=edit&section=11 "Rediger avsnitt: Referanser") | [rediger kilde](/w/index.php?title=FNs_sikkerhetsr%C3%A5d&action=edit&section=11 "Rediger kildekoden til seksjonen Referanser")]
#
#   1. **^** [FN-sambandets informasjonsside om Sikkerhetsrådet](http://www.fn.no/FN-informasjon/FNs-hovedorganer/Sikkerhetsraadet) [Arkivert](https://web.archive.org/web/20140204012210/http://www.fn.no/FN-informasjon/FNs-hovedorganer/Sikkerhetsraadet) 2014-02-04, hos [Wayback Machine](/wiki/Wayback_Machine "Wayback Machine").
#   2. **^** a b Jensen, Bjørn (1975). [_New York - kontrastenes metropol: med en snartur til Washington_](https://urn.nb.no/URN:NBN:no-nb_digibok_2007070501001). Oslo: Aschehoug. [ISBN](/wiki/ISBN "ISBN") [8203064965](/wiki/Spesial:Bokkilder/8203064965 "Spesial:Bokkilder/8203064965").
#   3. **^** <https://www.independent.co.uk/voices/trump-china-taiwan-deal-xi-jinping-north-korea-sea-a8707946.html>
#   4. **^** [«General Assembly Elects Estonia, Niger, Saint Vincent and Grenadines, Tunisia, Viet Nam as Non-Permanent Members of Security Council for 2020-2021»](https://www.un.org/press/en/2019/ga12152.doc.htm). United Nations. 7. juni 2019. Besøkt 3. mai 2020.
#   5. **^** kontor, Statsministerens (17. juni 2020). [«Norge valgt inn i FNs sikkerhetsråd»](https://www.regjeringen.no/nn/aktuelt/norge-valgt-inn-i-fns-sikkerhetsrad/id2714507/). _Regjeringa.no_ (på norsk nynorsk). Besøkt 18. juni 2020.
#   6. **^** [«ELECTION OF NON-PERMANENT MEMBERS OF THE SECURITY COUNCIL [113 (a)] 2nd Ballot»](https://www.un.org/pga/74/wp-content/uploads/sites/99/2020/06/Final-A-SC-elections-74TH-African-Asian-States-18-June-2020.pdf) (PDF). Besøkt 19. juni 2020.
#   7. **^** [«Fem nye medlemmer valgt inn i FNs sikkerhetsråd»](https://www.fn.no/nyheter/fem-nye-medlemmer-valgt-inn-i-fns-sikkerhetsraad). _www.fn.no_ (på norsk). Besøkt 3. januar 2022.
#   8. **^** [Countries Elected Members ](https://www.un.org/securitycouncil/content/countries-elected-members)
#   9. **^** [Current Members](https://www.un.org/securitycouncil/content/current-members) (lest 16.11.2022)
#   10. **^** Roalsø, Martin (17. juni 2020). [«Avstemningen i FN er over: Får Norge plass i Sikkerhetsrådet?»](https://www.nrk.no/urix/avstemningen-i-fn-er-over_-far-norge-plass-i-sikkerhetsradet_-1.15057460). _NRK_. Besøkt 17. juni 2020.
#   11. **^** [Utenriksdepartementet](/wiki/Utenriksdepartementet "Utenriksdepartementet") (15. april 2002). [«Oversikt over arbeidet i Sikkerhetsrådet mars 2002»](http://www.regjeringen.no/nb/dep/ud/dok/rapporter_planer/rapporter/2002/Oversikt-over-arbeidet-i-Sikkerhetsradet-mars-2002.html?id=105821). Besøkt 18. februar 2008.
#   12. **^** [«Security Council Presidency | United Nations Security Council»](https://www.un.org/securitycouncil/content/presidency). _www.un.org_. Besøkt 1. april 2023.
#
# ## Eksterne lenker
#
# [[rediger](/w/index.php?title=FNs_sikkerhetsr%C3%A5d&veaction=edit&section=12 "Rediger avsnitt: Eksterne lenker") | [rediger kilde](/w/index.php?title=FNs_sikkerhetsr%C3%A5d&action=edit&section=12 "Rediger kildekoden til seksjonen Eksterne lenker")]
#
#   * (en) [Offisielt nettsted](https://www.un.org/securitycouncil) [![Rediger på Wikidata](//upload.wikimedia.org/wikipedia/commons/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/20px-OOjs_UI_icon_edit-ltr-progressive.svg.png)](https://www.wikidata.org/wiki/Q37470?uselang=nb#P856 "Rediger på Wikidata")
#   * (en) [United Nations Security Council](https://commons.wikimedia.org/wiki/Category:United_Nations_Security_Council "commons:Category:United Nations Security Council") – kategori av bilder, video eller lyd på [Commons](/wiki/Wikimedia_Commons "Wikimedia Commons") [![Rediger på Wikidata](//upload.wikimedia.org/wikipedia/commons/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/20px-OOjs_UI_icon_edit-ltr-progressive.svg.png)](https://www.wikidata.org/wiki/Q37470?uselang=nb#P373 "Rediger på Wikidata")
#   * [Norges rolle i FNs sikkerhetsråd](https://www.fn.no/om-fn/norge-og-fn/norges-rolle-i-fns-sikkerhetsraad) [Arkivert](https://web.archive.org/web/20220103181658/https://www.fn.no/om-fn/norge-og-fn/norges-rolle-i-fns-sikkerhetsraad) 3\. januar 2022 hos [Wayback Machine](/wiki/Wayback_Machine "Wayback Machine").. [FN-sambandet](/wiki/FN-sambandet "FN-sambandet")
#
#   * [v](/wiki/Mal:FN "Mal:FN")
#   * [d](/w/index.php?title=Maldiskusjon:FN&action=edit&redlink=1 "Maldiskusjon:FN \(ikke skrevet ennå\)")
#   * [r](/wiki/Spesial:Rediger_side/Mal:FN "Spesial:Rediger side/Mal:FN")
#
# [De forente nasjoner (FN)](/wiki/De_forente_nasjoner "De forente nasjoner")
# ---
# Hovedorganer| [Generalforsamlingen](/wiki/FNs_generalforsamling "FNs
# generalforsamling") **·** Sikkerhetsrådet **·** [FNs økonomiske og sosiale
# råd](/wiki/FNs_%C3%B8konomiske_og_sosiale_r%C3%A5d "FNs økonomiske og sosiale
# råd") **·** [Sekretariatet](/wiki/FN-sekretariatet "FN-sekretariatet") **·**
# [Tilsynsrådet](/wiki/FNs_tilsynsr%C3%A5d "FNs tilsynsråd") (inaktivt) **·**
# [Den internasjonale domstolen](/wiki/Den_internasjonale_domstolen "Den
# internasjonale domstolen")|
# [![FN](//upload.wikimedia.org/wikipedia/commons/thumb/2/2f/Small_Flag_of_the_United_Nations_ZP.svg/120px-
# Small_Flag_of_the_United_Nations_ZP.svg.png)](/wiki/Fil:Small_Flag_of_the_United_Nations_ZP.svg
# "FN")
# [Særorganisasjoner](/wiki/FNs_s%C3%A6rorganisasjoner "FNs særorganisasjoner")|
# [FAO](/wiki/FNs_organisasjon_for_ern%C3%A6ring_og_landbruk "FNs organisasjon
# for ernæring og landbruk") **·**
# [ICAO](/wiki/Den_internasjonale_organisasjonen_for_sivil_luftfart "Den
# internasjonale organisasjonen for sivil luftfart") **·**
# [IFAD](/wiki/Det_internasjonale_fondet_for_jordbruksutvikling "Det
# internasjonale fondet for jordbruksutvikling") **·**
# [ILO](/wiki/Den_internasjonale_arbeidsorganisasjonen "Den internasjonale
# arbeidsorganisasjonen") **·** [IMF](/wiki/Det_internasjonale_pengefondet "Det
# internasjonale pengefondet") **·**
# [IMO](/wiki/Den_internasjonale_sj%C3%B8fartsorganisasjonen "Den internasjonale
# sjøfartsorganisasjonen") **·**
# [ITU](/wiki/Den_internasjonale_telekommunikasjonsunion "Den internasjonale
# telekommunikasjonsunion") **·** [UNESCO](/wiki/UNESCO "UNESCO") **·**
# [UNIDO](/wiki/FNs_organisasjon_for_industriell_utvikling "FNs organisasjon for
# industriell utvikling") **·** [UNWTO](/wiki/Verdens_turismeorganisasjon
# "Verdens turismeorganisasjon") **·** [UPU](/wiki/Verdenspostforeningen
# "Verdenspostforeningen") **·** [VBG](/wiki/Verdensbanken "Verdensbanken")
# **·** [WHO](/wiki/Verdens_helseorganisasjon "Verdens helseorganisasjon") **·**
# [WIPO](/wiki/Den_internasjonale_opphavsrettsorganisasjonen "Den internasjonale
# opphavsrettsorganisasjonen") **·** [WMO](/wiki/Verdens_meteorologiorganisasjon
# "Verdens meteorologiorganisasjon")
# Andre programmer og byråer|
# [IAEA](/wiki/Det_internasjonale_atomenergibyr%C3%A5et "Det internasjonale
# atomenergibyrået") **·** [UNCTAD](/wiki/FN-konferansen_om_handel_og_utvikling
# "FN-konferansen om handel og utvikling") **·**
# [UNDCP](/wiki/FNs_kontor_for_narkotika_og_kriminalitet "FNs kontor for
# narkotika og kriminalitet") **·** [UNDP](/wiki/FNs_utviklingsprogram "FNs
# utviklingsprogram") **·** [UNEP](/wiki/FNs_milj%C3%B8program "FNs
# miljøprogram") **·** [UNFPA](/wiki/FNs_befolkningsfond "FNs befolkningsfond")
# **·** [UNHCR](/wiki/FNs_h%C3%B8ykommiss%C3%A6r_for_flyktninger "FNs
# høykommissær for flyktninger") **·**
# [UNHRC](/wiki/FNs_menneskerettighetsr%C3%A5d "FNs menneskerettighetsråd")
# **·** [UN–Habitat](/wiki/FNs_bosettingsprogram "FNs bosettingsprogram") **·**
# [UNICEF](/wiki/UNICEF "UNICEF") **·**
# [UNRWA](/wiki/FNs_hjelpeorganisasjon_for_palestinske_flyktninger_i_Midt%C3%B8sten
# "FNs hjelpeorganisasjon for palestinske flyktninger i Midtøsten") **·**
# [WFP](/wiki/Verdens_matvareprogram "Verdens matvareprogram") **·**
# [UNECE](/wiki/FNs_%C3%B8konomikommisjon_for_Europa "FNs økonomikommisjon for
# Europa") **·**
# [UNECA](/wiki/De_forente_nasjoners_%C3%B8konomiske_kommisjon_for_Afrika "De
# forente nasjoners økonomiske kommisjon for Afrika") **·**
# [UNESCAP](/wiki/FNs_%C3%B8konomi-_og_sosialkommisjon_for_Asia_og_Stillehavet
# "FNs økonomi- og sosialkommisjon for Asia og Stillehavet") **·**
# [UNRRA](/wiki/United_Nations_Relief_and_Rehabilitation_Administration "United
# Nations Relief and Rehabilitation Administration")
# Annet| [Medlemmer](/wiki/FNs_medlemsland "FNs medlemsland") **·**
# [Observatører](/wiki/Observat%C3%B8rstatus_i_FNs_hovedforsamling
# "Observatørstatus i FNs hovedforsamling") **·**
# [Generalsekretærer](/wiki/FNs_generalsekret%C3%A6r "FNs generalsekretær")
# **·** [Sikkerhetsrådets
# resolusjoner](/wiki/Kategori:Sikkerhetsr%C3%A5dets_resolusjoner
# "Kategori:Sikkerhetsrådets resolusjoner") **·** [Fredsbevarende
# styrker](/wiki/FNs_fredsbevarende_styrker "FNs fredsbevarende styrker") **·**
# [FN-dager](/wiki/Liste_over_FN-dager "Liste over FN-dager")
#
#   * [v](/wiki/Mal:Sikkerhetsr%C3%A5det "Mal:Sikkerhetsrådet")
#   * [d](/w/index.php?title=Maldiskusjon:Sikkerhetsr%C3%A5det&action=edit&redlink=1 "Maldiskusjon:Sikkerhetsrådet \(ikke skrevet ennå\)")
#   * [r](/wiki/Spesial:Rediger_side/Mal:Sikkerhetsr%C3%A5det "Spesial:Rediger side/Mal:Sikkerhetsrådet")
#
# Medlemmer av [FNs](/wiki/De_forente_nasjoner "De forente nasjoner")
# sikkerhetsråd
# ---
# Faste medlemmer| [Frankrike](/wiki/Frankrike "Frankrike") **·**
# [Kina](/wiki/Kina "Kina") **·** [Russland](/wiki/Russland "Russland") **·**
# [Storbritannia](/wiki/Storbritannia "Storbritannia") **·** [USA](/wiki/USA
# "USA")|
# [![](//upload.wikimedia.org/wikipedia/commons/thumb/2/2f/Small_Flag_of_the_United_Nations_ZP.svg/120px-
# Small_Flag_of_the_United_Nations_ZP.svg.png)](/wiki/Fil:Small_Flag_of_the_United_Nations_ZP.svg)
# Rullerende medlemsland
# (toårig medlemskap)| | 2023–2024| [Ecuador](/wiki/Ecuador "Ecuador") **·** [Japan](/wiki/Japan "Japan") **·** [Malta](/wiki/Malta "Malta") **·** [Mosambik](/wiki/Mosambik "Mosambik") **·** [Sveits](/wiki/Sveits "Sveits")[_[trenger oppdatering](/wiki/Kategori:Opplysninger_som_trenger_oppdatering "Kategori:Opplysninger som trenger oppdatering")_]
# ---|---
# 2024–2025| [Algerie](/wiki/Algerie "Algerie") **·** [Guyana](/wiki/Guyana
# "Guyana") **·** [Sierra Leone](/wiki/Sierra_Leone "Sierra Leone") **·**
# [Slovenia](/wiki/Slovenia "Slovenia") **·** [Sør-Korea](/wiki/S%C3%B8r-Korea
# "Sør-Korea")
#
# [Oppslagsverk/autoritetsdata](/wiki/Hjelp:Autoritetsdata
# "Hjelp:Autoritetsdata")| [Store norske
# leksikon](https://snl.no/FNs_sikkerhetsråd) **·** [Store Danske
# Encyklopædi](https://denstoredanske.lex.dk/FN's_Sikkerhedsråd) **·**
# [Encyclopædia Britannica](https://www.britannica.com/topic/United-Nations-
# Security-Council) **·**
# [Nationalencyklopedin](https://www.ne.se/uppslagsverk/encyklopedi/lång/s%C3%A4kerhetsr%C3%A5det)
# **·** [BIBSYS](http://bibsys-
# almaprimo.hosted.exlibrisgroup.com/primo_library/libweb/action/dlSearch.do?institution=BIBSYS&vid=BIBSYS&search_scope=blended_scope&query=lsr39,exact,90186219)
# **·** [VIAF](https://viaf.org/viaf/141892099) **·**
# [GND](https://d-nb.info/gnd/1001797-5) **·**
# [LCCN](https://id.loc.gov/authorities/n80076467) **·**
# [ISNI](http://isni.org/0000000121720195) **·**
# [BNF](https://catalogue.bnf.fr/ark:/12148/cb12078331x) **·** [BNF
# (data)](http://data.bnf.fr/ark:/12148/cb12078331x) **·**
# [LIBRIS](https://libris.kb.se/ljx02lw40c7zgvg) **·**
# [SUDOC](https://www.idref.fr/029083699) **·**
# [NLA](https://librariesaustralia.nla.gov.au/search/display?dbid=auth&id=35562076)
# **·** [NDL](https://id.ndl.go.jp/auth/ndlna/00634552) **·**
# [NKC](https://aleph.nkp.cz/F/?func=find-c&local_base=aut&ccl_term=ica=kn20010711346)
# **·** [CiNii](https://ci.nii.ac.jp/author/DA03206090) **·** [BBC
# Things](https://www.bbc.co.uk/things/b74f28ac-bbb9-4103-a18e-856aee7ad9a2)
# ---|---
#   *[v]: Vis denne malen
#   *[d]: Diskuter denne malen
#   *[r]: Rediger denne malen
